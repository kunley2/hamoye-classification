# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import classification_report,accuracy_score
from xgboost import XGBClassifier,XGBModel
from lightgbm import LGBMClassifier,LGBMModel

# %%
elect_grid_df = pd.read_csv('Data_for_UCI_named.csv')
elect_grid_df
# Out:
#           tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0     2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1     9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2     8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3     0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4     3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  2.930406  9.487627  2.376523  6.187797  3.343416 -0.658054 -1.449106
# 9996  3.392299  1.274827  2.954947  6.894759  4.349512 -1.663661 -0.952437
# 9997  2.364034  2.842030  8.776391  1.008906  4.299976 -1.380719 -0.943884
# 9998  9.631511  3.994398  2.757071  7.821347  2.514755 -0.966330 -0.649915
# 9999  6.530527  6.781790  4.349695  8.673138  3.492807 -1.390285 -1.532193
#
# ...

# %%
precision = 355/(355+1480)

# %%
recall = 355/(355+45)

# %%
f1 = 2*((precision*recall)/(precision+recall))
f1
# Out:
# 0.3176733780760626

# %%
elect_grid_df.drop(columns='stab',inplace=True)

# %%
x=elect_grid_df.drop(columns='stabf')
y = elect_grid_df[['stabf']]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=1,test_size=0.2)

# %%
x
# Out:
#           tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0     2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1     9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2     8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3     0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4     3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  2.930406  9.487627  2.376523  6.187797  3.343416 -0.658054 -1.449106
# 9996  3.392299  1.274827  2.954947  6.894759  4.349512 -1.663661 -0.952437
# 9997  2.364034  2.842030  8.776391  1.008906  4.299976 -1.380719 -0.943884
# 9998  9.631511  3.994398  2.757071  7.821347  2.514755 -0.966330 -0.649915
# 9999  6.530527  6.781790  4.349695  8.673138  3.492807 -1.390285 -1.532193
#
#             p4        g1        g2        g3        g4
# ...

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
forest = RandomForestClassifier(random_state=1)
forest.fit(x_train,y_train)
y_predict = forest.predict(x_test)
# print(forest.score())
print(round(accuracy_score(y_test,y_predict),5))
# Out:
# <ipython-input-30-034771e9d446>:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   forest.fit(x_train,y_train)
# 0.929

# %%
xgb=XGBClassifier(random_state=1)
xgb.fit(x_train,y_train)
y_predict = xgb.predict(x_test)
# print(forest.score())
print((accuracy_score(y_test,y_predict)))
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# ...

# %%
lg = LGBMClassifier(random_state=1)
lg.fit(x_train,y_train)
y_predict = lg.predict(x_test)
# print(forest.score())
print((accuracy_score(y_test,y_predict)))
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# 0.9395

# %%
n_estimators = [50, 100, 300, 500, 1000]

min_samples_split = [2, 3, 5, 7, 9]

min_samples_leaf = [1, 2, 4, 6, 8]

max_features = ['auto', 'sqrt', 'log2', None]

hyperparameter_grid = {'n_estimators': n_estimators,

'min_samples_leaf': min_samples_leaf,

'min_samples_split': min_samples_split,

'max_features': max_features}
max_features = ['auto', 'sqrt', 'log2', None] 
cv = RandomizedSearchCV(ExtraTreesClassifier(),param_distributions=hyperparameter_grid,random_state=1,cv=5,n_iter=10,
                       scoring='accuracy',n_jobs=-1,verbose=1)
cv.fit(x_train,y_train)
y_predict = cv.predict(x_test)
print(accuracy_score(y_test,y_predict))
print(cv.best_params_)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:880: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)
# 0.9295
# {'n_estimators': 1000, 'min_samples_split': 2, 'min_samples_leaf': 8, 'max_features': None}

# %%
tree = ExtraTreesClassifier(n_estimators= 1000, min_samples_split=2, min_samples_leaf=8)
tree.fit(x_train,y_train)
y_pred = tree.predict(x_test)
print(tree.feature_importances_)
dataframe = pd.DataFrame(x.columns)
dataframe['importance']= tree.feature_importances_
dataframe
# Out:
# <ipython-input-28-16659d72a057>:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   tree.fit(x_train,y_train)
# [0.14063205 0.14646915 0.13666827 0.13837233 0.00734951 0.00993639
#  0.00996398 0.00997356 0.09161684 0.10277779 0.10591311 0.10032701]
#        0  importance
# 0   tau1    0.140632
# 1   tau2    0.146469
# 2   tau3    0.136668
# 3   tau4    0.138372
# 4     p1    0.007350
# 5     p2    0.009936
# 6     p3    0.009964
# 7     p4    0.009974
# 8     g1    0.091617
# 9     g2    0.102778
# 10    g3    0.105913
# 11    g4    0.100327

# %%
n_estimators = [50, 100, 300, 500, 1000]

min_samples_split = [2, 3, 5, 7, 9]

min_samples_leaf = [1, 2, 4, 6, 8]

max_features = ['auto', 'sqrt', 'log2', None]

hyperparameter_grid = {'n_estimators': n_estimators,

'min_samples_leaf': min_samples_leaf,

'min_samples_split': min_samples_split,

'max_features': max_features}
max_features = ['auto', 'sqrt', 'log2', None] 
cv = RandomizedSearchCV(ExtraTreesClassifier(),param_distributions=hyperparameter_grid,random_state=1)
cv.fit(x_train,y_train)
y_predict = cv.predict(x_test)
print(accuracy_score(y_test,y_predict))
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...
